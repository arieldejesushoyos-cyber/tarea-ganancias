# %%
A=int(input("materia prima ? "))
b=int(input("empaque? "))
c=int(input("transporte? "))
total=A+b+c
print("total:$",total)
v=int(input("¿cuanto vende? "))
print("ganancias:$",v-total)
# Out:
# materia prima ? 5000
# empaque? 10000
# transporte? 30000
# total:$ 45000
# ¿cuanto vende? 60000
# ganancias:$ 15000
